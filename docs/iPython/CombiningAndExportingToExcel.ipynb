# %% [markdown]
# ### Combining and Exporting
#
# In this notebook we will learn how to combine Pandas DataFrames together using the [`.concat()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.concat.html) and the [`.merge()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.merge.html) funtions from Pandas.
#
# The main differences is that `.merge()` will combine dataframes on a common index whereas `.concat()` will either stack the dataframes on top of eachother or side by side depending on the parameters passed.
#
# At the end we will also learn how to export them to an Excel file. __NOTE__ for this you will have to install libraries `xlrd` and `xlsxwriter`.

# %%
import pandas as pd
# %store -r df1
# %store -r df2
# %store -r df3

# %% [markdown]
# Okay, lets take a look at the `concat()` function. Probably the most important argument to pass is the dataframes you would like to concatenate. I have passed `[df3, df2]` as the first argument, which if you remember were the excel sheets with metadata from my local machine. The second arguement `ignore_index: boolean` will ignore the index for concatenation when true. This is helpful when the index is not relevant. For us the index was automatically set and appears as the list on the lefthand side of the dataframe. Setting `ignore_index` to `True` will allow those numbers to be renamed to the total length of the rows (i.e 0,...,n-1).
#
# I also dropped some columns to get to the barebones metadata that I was looking at.

# %%
dfm = pd.concat([df3, df2], ignore_index=True)
dfm = dfm.drop(['sparrow order', 'id', 'technique', 'Irradiation', 'phase', 'sample_name.1', 'GeoDeepDive ping?',
                'Comments', 'Notes'], axis=1)
dfm
# Out:
#      sample_name            lithology   latitude   longitude elevation_m  \
# 0      SEG 03 32        rhyolite dome  52.351166 -175.417000         NaN
# 1      SEG 03 44     dacitic ash flow  52.351166 -175.417000         NaN
# 2      SEG 03 66  andesitic lava flow  52.283300 -172.403300         NaN
# 3      SEG 03 03    dacitic lava flow  52.375000 -172.389166         NaN
# 4        SB87–56  rhyolitic lava flow  52.266833 -172.522166         NaN
# ...          ...                  ...        ...         ...         ...
# 2295     LDM249A                  NaN -35.986620  -70.494220        2351
# 2296      LDM500                  NaN -36.174940  -70.395310         NaN
# 2297        LDM6                  NaN        NaN         NaN         NaN
# 2298        LDM6                  NaN        NaN         NaN         NaN
# 2299       LDM60                  NaN        NaN         NaN         NaN
#
#      depth_m                       Formation  \
# 0        NaN  Seguam Island Volcanic Complex
# 1        NaN  Seguam Island Volcanic Complex
# 2        NaN  Seguam Island Volcanic Complex
# 3        NaN  Seguam Island Volcanic Complex
# 4        NaN  Seguam Island Volcanic Complex
# ...      ...                             ...
# 2295     NaN                             NaN
# 2296     NaN                             NaN
# 2297     NaN                             NaN
# 2298     NaN                             NaN
# 2299     NaN                             NaN
#
#                                        Member        author    year  \
# 0     Rhyolite flow in crater valley (7.5 ka)  Jicha et al.  2005.0
# 1                          Dacitic Ignimbrite  Jicha et al.  2005.0
# 2                           Lava Point Dacite  Jicha et al.  2005.0
# 3                       Finch Cove Rhyodacite  Jicha et al.  2005.0
# 4     Basaltic to Rhyolitic South Shore Lavas  Jicha et al.  2005.0
# ...                                       ...           ...     ...
# 2295                                      NaN           NaN     NaN
# 2296                                      NaN           NaN     NaN
# 2297                                      NaN           NaN     NaN
# 2298                                      NaN           NaN     NaN
# 2299                                      NaN           NaN     NaN
#
#                                   journal  \
# 0     Earth and Planetary Science Letters
# 1     Earth and Planetary Science Letters
# 2     Earth and Planetary Science Letters
# 3     Earth and Planetary Science Letters
# 4     Earth and Planetary Science Letters
# ...                                   ...
# 2295                                  NaN
# 2296                                  NaN
# 2297                                  NaN
# 2298                                  NaN
# 2299                                  NaN
#
#                                                   Title  \
# 0     Contrasting timescales of crystallization and ...
# 1     Contrasting timescales of crystallization and ...
# 2     Contrasting timescales of crystallization and ...
# 3     Contrasting timescales of crystallization and ...
# 4     Contrasting timescales of crystallization and ...
# ...                                                 ...
# 2295                                                NaN
# 2296                                                NaN
# 2297                                                NaN
# 2298                                                NaN
# 2299                                                NaN
#
#                                         doi_link Where_to_Find Unit/Formation  \
# 0     https://doi.org/10.1016/j.epsl.2005.05.002           NaN            NaN
# 1     https://doi.org/10.1016/j.epsl.2005.05.002           NaN            NaN
# 2     https://doi.org/10.1016/j.epsl.2005.05.002           NaN            NaN
# 3     https://doi.org/10.1016/j.epsl.2005.05.002           NaN            NaN
# 4     https://doi.org/10.1016/j.epsl.2005.05.002           NaN            NaN
# ...                                          ...           ...            ...
# 2295                                         NaN           NaN            NaN
# 2296                                         NaN           NaN            NaN
# 2297                                         NaN           NaN            NaN
# 2298                                         NaN           NaN            NaN
# 2299                                         NaN           NaN            NaN
#
#      Unpublished                Where_to_find_it From_PI Unnamed: 24
# 0            NaN                             NaN     NaN         NaN
# 1            NaN                             NaN     NaN         NaN
# 2            NaN                             NaN     NaN         NaN
# 3            NaN                             NaN     NaN         NaN
# 4            NaN                             NaN     NaN         NaN
# ...          ...                             ...     ...         ...
# 2295         NaN  Andersen Paper if not ask brad     NaN         NaN
# 2296         NaN  Andersen Paper if not ask brad     NaN         NaN
# 2297         NaN  Andersen Paper if not ask brad     NaN         NaN
# 2298         NaN  Andersen Paper if not ask brad     NaN         NaN
# 2299         NaN  Andersen Paper if not ask brad     NaN         NaN
#
# [2300 rows x 19 columns]

# %% [markdown]
# The `.merge()` function. Here we set the index for both dataframes before we merge. For this function we attach it as a dot function to the first dataframe and include the dataframe we are merging with as the first argument. There are a lot of other arguments I have included, but it is basically just telling the function to use both indexes as join keys.
#
# The result is a dataframe where the totality of df1 is on the left and then dfm is on the right. This can be helpful because as we can see as we scroll through the dataframe, dfm, the dataframe from the local machine, has many more samples compared to df1, fetched from the API. This right away tells us that there is new data that we can upload to the API.

# %%
df1.set_index('name')
dfm.set_index('sample_name')

dfmerged = df1.merge(dfm, how='outer', on=None, left_on=None, right_on=None, left_index=True, right_index=True)
dfmerged
# Out:
#              name    material location_name location_name_autoset is_public  \
# 0             M2C  Lava Flows          None                  None      True
# 1         90T151A       Baslt          None                  None      True
# 2         90T050B       Baslt          None                  None      True
# 3        84C207AB        None          None                  None      True
# 4     LDMEB-13-21      Dacite          None                  None      True
# ...           ...         ...           ...                   ...       ...
# 2295          NaN         NaN           NaN                   NaN       NaN
# 2296          NaN         NaN           NaN                   NaN       NaN
# 2297          NaN         NaN           NaN                   NaN       NaN
# 2298          NaN         NaN           NaN                   NaN       NaN
# 2299          NaN         NaN           NaN                   NaN       NaN
#
#       Longitude   Latitude sample_name            lithology   latitude  ...  \
# 0       -149.66     -17.66   SEG 03 32        rhyolite dome  52.351166  ...
# 1     -156.2311    20.6368   SEG 03 44     dacitic ash flow  52.351166  ...
# 2     -156.2311    20.6368   SEG 03 66  andesitic lava flow  52.283300  ...
# 3          None       None   SEG 03 03    dacitic lava flow  52.375000  ...
# 4      -70.5921  -36.00909     SB87–56  rhyolitic lava flow  52.266833  ...
# ...         ...        ...         ...                  ...        ...  ...
# 2295        NaN        NaN     LDM249A                  NaN -35.986620  ...
# 2296        NaN        NaN      LDM500                  NaN -36.174940  ...
# 2297        NaN        NaN        LDM6                  NaN        NaN  ...
# 2298        NaN        NaN        LDM6                  NaN        NaN  ...
# 2299        NaN        NaN       LDM60                  NaN        NaN  ...
#
#         year                              journal  \
# 0     2005.0  Earth and Planetary Science Letters
# 1     2005.0  Earth and Planetary Science Letters
# 2     2005.0  Earth and Planetary Science Letters
# 3     2005.0  Earth and Planetary Science Letters
# 4     2005.0  Earth and Planetary Science Letters
# ...      ...                                  ...
# 2295     NaN                                  NaN
# 2296     NaN                                  NaN
# 2297     NaN                                  NaN
# 2298     NaN                                  NaN
# 2299     NaN                                  NaN
#
#                                                   Title  \
# 0     Contrasting timescales of crystallization and ...
# 1     Contrasting timescales of crystallization and ...
# 2     Contrasting timescales of crystallization and ...
# 3     Contrasting timescales of crystallization and ...
# 4     Contrasting timescales of crystallization and ...
# ...                                                 ...
# 2295                                                NaN
# 2296                                                NaN
# 2297                                                NaN
# 2298                                                NaN
# 2299                                                NaN
#
#                                         doi_link Where_to_Find Unit/Formation  \
# 0     https://doi.org/10.1016/j.epsl.2005.05.002           NaN            NaN
# 1     https://doi.org/10.1016/j.epsl.2005.05.002           NaN            NaN
# 2     https://doi.org/10.1016/j.epsl.2005.05.002           NaN            NaN
# 3     https://doi.org/10.1016/j.epsl.2005.05.002           NaN            NaN
# 4     https://doi.org/10.1016/j.epsl.2005.05.002           NaN            NaN
# ...                                          ...           ...            ...
# 2295                                         NaN           NaN            NaN
# 2296                                         NaN           NaN            NaN
# 2297                                         NaN           NaN            NaN
# 2298                                         NaN           NaN            NaN
# 2299                                         NaN           NaN            NaN
#
#       Unpublished                Where_to_find_it From_PI Unnamed: 24
# 0             NaN                             NaN     NaN         NaN
# 1             NaN                             NaN     NaN         NaN
# 2             NaN                             NaN     NaN         NaN
# 3             NaN                             NaN     NaN         NaN
# 4             NaN                             NaN     NaN         NaN
# ...           ...                             ...     ...         ...
# 2295          NaN  Andersen Paper if not ask brad     NaN         NaN
# 2296          NaN  Andersen Paper if not ask brad     NaN         NaN
# 2297          NaN  Andersen Paper if not ask brad     NaN         NaN
# 2298          NaN  Andersen Paper if not ask brad     NaN         NaN
# 2299          NaN  Andersen Paper if not ask brad     NaN         NaN
#
# [2300 rows x 26 columns]

# %% [markdown]
# We now have a couple large dataframes that are showing us large amounts of data together. It may be helpful to have these as excel sheets. Excel sheets may be easier to navigate for people unfamiliar with python and they can easily be shared with teams.
#
# To export these dataframes to excel we will be using the `xlsxwriter` as the writing machine. The first thing we need is a variable that calls *xlsxwriter* and gives the name that we want to call our new excel file. We then use the `.to_excel()` function to tell pandas to turn a dataframe into an excel file and we will pass the varible we made as the first argument and we can also pass an argument to name the sheet. Then we save the first variable using `.save()`.
#
# `writer2 = pd.ExcelWriter('Comparison_Sheet.xlsx', engine='xlsxwriter')
# dfmerged.to_excel(writer2, sheet_name='Sheet_1')
# writer2.save()`

# %%
# %store dfmerged
# %store dfm
# Out:
# Stored 'dfmerged' (DataFrame)
# Stored 'dfm' (DataFrame)
