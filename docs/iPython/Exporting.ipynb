# %% [markdown]
# In the proccess of analyzing your data, you may want to create a specific excel sheet for only samples that you still need to find metadata for. We can get a list of samples that still need metadata the same way we found what samples to upload. But that is just a list of names then. How do we recreate the dataframe with every column for that sample?
#
# First I'll make a list of samples missing metadata still.

# %%
import pandas as pd
from pandas import isnull
import numpy as np
import json
# %store -r dfOnline
# %store -r dfm
# %store -r df1
# %store -r Uploadable_total

# %%
Missing = []
dfOnline.Names = dfOnline.Names.astype('str')
for i, series in dfOnline.iterrows():
    if (isnull(series.Longitude)) is True:
        Missing.append(series.Names)
Missing
# Out:
# ['84C207AB',
#  '90T112B',
#  'SMUB-13',
#  'CH9-18',
#  '86C471B',
#  'AT80-36',
#  'CH9-11',
#  'AT11',
#  'GR-11-103',
#  'NI-010813-7',
#  'NI-010913-12',
#  'NI-011013-14',
#  'NI-010813-4',
#  'GUAZAPA',
#  '30AL-2',
#  '19A-1-14-12-10-11',
#  '161-AL-15-04-225',
#  'ANGAREB_DIKE',
#  '141-AL-15-04-20-01',
#  '141-AL-15-04-20-1',
#  '32AL-4',
#  'AL-13-9',
#  '1-9-5-12',
#  '9-10-5-12',
#  '84C436A',
#  '84C207A',
#  '09RAYJR078A',
#  '09RAYJR203B',
#  'HP-22',
#  '09RAYJR111A',
#  'HP-17',
#  'LS-5',
#  'LS-6',
#  'LS-7',
#  'LS-3',
#  'LS-1',
#  'LS-4',
#  'LS-2',
#  '10RAYJR049A1',
#  '10RAYJR099A1',
#  '10RAYJR102A1',
#  '10RAYJR104A2',
#  '10RAYJR076A1',
#  '10RAYJR079B1',
#  '10RAYJR077A1',
#  'WO-45',
#  'WO-46',
#  'WO-11',
#  '129SR',
#  'JC1-5B',
#  'JC24B-3A',
#  'JC1-3A',
#  'AM4',
#  'AM1',
#  'UAE3603',
#  'UAE6260',
#  'UAE5308',
#  'MI-3',
#  'DB2',
#  'MI-6',
#  'R2',
#  'DB2A',
#  'R1',
#  'MI-7',
#  'PK14-H-1',
#  'EFS15-A-1',
#  'BE21',
#  'BE26',
#  'BE25',
#  'BE29',
#  'BE19',
#  'BE22',
#  'BE31',
#  'BE10',
#  'BE33',
#  'BE23',
#  'LDM-60',
#  'LDM',
#  'PIG-11-05',
#  'SAN-11-02',
#  'SAN-11-01',
#  'PIG-11-04',
#  'PIG-11-01',
#  'SAN-11-03',
#  'BAR-11-01',
#  'PIG-11-03B',
#  'TAZ-11-01',
#  'LDM210',
#  'LDM60',
#  '14AKMC051',
#  '14AKMC053',
#  '14AKMC061',
#  '11BT-11',
#  '11BT-8',
#  '10RAYJR013A2',
#  '10RAYMC034A1',
#  '10RAYJR048A1',
#  '10RAYJR013A1',
#  '10RAYJR016A2',
#  '10RAYJR064A1',
#  '09RAYRS153A1',
#  '10RAYKJR002B1',
#  '09RAYKR151A',
#  'BUR-120711-8',
#  'WO-48',
#  'WO-49',
#  'BUR-120711-9',
#  'HO9-22',
#  'NB129.1',
#  'AR27',
#  'BG139',
#  'LA-D11-004',
#  '05-LA-209',
#  'MD-07',
#  'MD-09',
#  'LA-D11-025',
#  'LA-D11-016',
#  'LA-D11-034',
#  'MD-10',
#  'AZ-091613-2',
#  'OS-120811-2',
#  'AZ-091513-18',
#  'AZ-091613-3',
#  'ATAN-11-02',
#  'ANDA-11-04',
#  'ANDA-11-06',
#  'ANDA-11-05',
#  'ATAN-11-13',
#  'SAN-11-04',
#  'ANDA-11-03',
#  'CHAV-11-21',
#  'PUQ-11-11',
#  'SAN-11-06',
#  'CCAR11-07',
#  'ATAN-11-11',
#  'LDM194',
#  'LDM213',
#  'LDM6',
#  'ES-13-15',
#  'WO29',
#  '72-44-A',
#  'WO52',
#  'BE14',
#  'FICON',
#  'BE1',
#  'TRIF',
#  'I-4388',
#  'I-4389',
#  'TGCPB',
#  'FALLFPP',
#  'FALLEPP',
#  'C5 5A',
#  'NEMI',
#  'TRP-FF',
#  'LDM249',
#  'SE08111124',
#  'HALLAA8',
#  'HALLAA2',
#  'HALLAA4',
#  'HALLAA6',
#  'HALLAA7',
#  'CLK1060C',
#  'K10701B',
#  'CLK1049B',
#  'GD0103B',
#  'K10703A',
#  'GA0205A',
#  '0115Y',
#  '10RMG047',
#  '10RMG057',
#  'UINTA',
#  '10RMG037',
#  '10RMG049',
#  'MP260112-1',
#  'F1461',
#  'PKS16-AG-1',
#  '14AKMC066',
#  'LA-03-2A',
#  'P5',
#  'K11-771',
#  'PT8',
#  'K90-4655',
#  'U9',
#  'U11',
#  'K09-620',
#  'LOWEROHAIR',
#  '13LAN62.0',
#  '13LAN30.3',
#  '13THE420',
#  '12AKMC008',
#  '12AKMC001',
#  '12AKMC006',
#  '12AKMC010',
#  '12AKMC002',
#  'PKS16-F-1',
#  'HALL-AA-16',
#  '10AVBB6',
#  '1232R07H01',
#  '10AVBB3',
#  '10AVBB2',
#  '10AVBB5',
#  '10AVBB1',
#  'KAG-12-09',
#  'KAG-12-01',
#  'KAG-12-03',
#  'HALLAA5',
#  'HALLAA10',
#  'ACS2',
#  'KEVIN410',
#  '14-28-7-05',
#  'SE0105109',
#  'SE010510-9',
#  'K09-647',
#  '14AKMC056',
#  'ES-13-01',
#  'ES-13-02',
#  'ES-13-03',
#  'ES-13-10',
#  'RB1612',
#  'RB1620',
#  'RB1614',
#  'RB1638',
#  'HF1601',
#  'RB1617',
#  'MV1501',
#  'RB1634',
#  'PGM15-A-2',
#  'PGM15-C-1',
#  'K15-1070',
#  'BCL15-A-1',
#  'BSP15-A-1',
#  'LUKENYA',
#  'BG153',
#  'BG134B',
#  'AR160',
#  'BG122',
#  'BG152',
#  'BG135A',
#  'ES-13-04',
#  'ES-13-20',
#  'ES-16-54',
#  '14JF2',
#  'ES-16-55',
#  'ES-15-39',
#  'ES-16-56',
#  'PIG-12-07',
#  'PIG-12-48',
#  'CH-13-05',
#  'PIG-12-09',
#  'PIG-12-08',
#  'PIG-12-46',
#  'PIG-12-06',
#  'PIG-12-47',
#  'OIS-12-01',
#  'AT80-32',
#  'AT80-76',
#  'AT19',
#  'AT5',
#  '84AYB629B',
#  '78ADT053',
#  '82AWS04',
#  '83ADT068A',
#  '83ADT067A',
#  '79ADT99',
#  '120-04',
#  '83ARJ216A',
#  '83AYB564',
#  '77AWS12',
#  '78AWS119',
#  '77ADT99',
#  '86ARJ109A',
#  'SR80-5A',
#  'MP80-15',
#  'HB8-25',
#  'MB80-15A',
#  'ES-13-14',
#  'ES-13-16',
#  'ES-13-17',
#  'ES-13-09',
#  'ES-13-08',
#  'ES-13-06',
#  'ES-13-12',
#  'BG121',
#  'BG166',
#  'ES-13-07',
#  'AR26',
#  'ES-13-13',
#  'BG115',
#  'CH247',
#  'CR235',
#  'E031655',
#  'S1221006',
#  'D031708',
#  'K031620',
#  'CR232',
#  'CI246',
#  'CH254',
#  'HB5-129',
#  '138SR',
#  'UB-1',
#  'AT80-71',
#  'A-51-3',
#  'HC-13-01',
#  'AMELIA',
#  'LOOKOUT',
#  'TUREMANRANCH',
#  'SCA-1',
#  'CAS-4',
#  'O1',
#  'C-5',
#  'LF-1',
#  'BC-8',
#  'KITT-3',
#  'BC-12',
#  'SE-1',
#  'AT-12-06',
#  'AT-12-02',
#  'GR-11-72',
#  'GR-11-112',
#  'SH-1A',
#  'AGR',
#  '12AKMC007',
#  'K13-836',
#  'SKEL-5',
#  'SBGL',
#  'PEDRO',
#  'CPAL',
#  'EDG',
#  'DF-134',
#  'DF-135',
#  'SM-2B',
#  'TR87-8',
#  'TR87-9',
#  'SM-2A',
#  '3504',
#  '858HC',
#  '840HC',
#  '828HC',
#  '821HC',
#  'ES-15-37',
#  'ES-15-47',
#  'BE11',
#  'BE7',
#  'BE3',
#  'BE5',
#  'SO201-1B-DR44-9',
#  'SO201-1B-DR44-3',
#  '85AYB221',
#  'TU012',
#  'TU044',
#  'TU004',
#  'TU033',
#  'TU025',
#  'PLT-15-C-2',
#  'BHS15-K-1',
#  'TYW15-A-1',
#  'BT-15-A-2',
#  'BE20',
#  'CLK11-192',
#  'BE4',
#  'INF970',
#  'CAT125',
#  'CLK11148A2',
#  'CLK11138A3',
#  'BE15',
#  'CLK11138A2',
#  '11RAYAZ212B',
#  '11RAYAZ122A',
#  '11RAYAZ354A3',
#  '11RAYAZ426A',
#  '11RAYAZ110A',
#  '11RAYAZ300A',
#  '11RAYAZ324A',
#  '11RAYAZ036A',
#  '14HT-1',
#  'HB6-10',
#  'I8-1',
#  '14LM-1',
#  '09RAYMC036A',
#  '10RAYJR063',
#  '11JA20-01',
#  '11JA20-05',
#  '11JA29-07',
#  '09JN08-03',
#  '09RAYMC050A',
#  '98L-2010',
#  '51-L-8',
#  'TIMFLOOD',
#  '51-N-23',
#  '1178128',
#  'KAN80-7-20',
#  'HP-18A',
#  '118314',
#  'GA1114',
#  'ANDA-11-01',
#  'ANDA-11-02',
#  'UM-05-2E',
#  'R03',
#  'P07',
#  'U08',
#  'P05',
#  '52-SN-160',
#  'SE-040611-4',
#  'SO201-1B-DR19-1',
#  'BE9',
#  'BE8',
#  'BE12',
#  'BE18',
#  'KAN80-6-27',
#  '52-SN-141',
#  '52-SN-147',
#  '51-SN-11',
#  '51-P-37',
#  '09JN08-04',
#  '09JN10-12',
#  '09JN09-02',
#  '09JN17-1B',
#  '09JN27-5B',
#  '09JN08-05',
#  '09JN12-11',
#  '09JN17-1A',
#  '09JN03-2A',
#  '11RAYJR261A',
#  '11RAYJR141A',
#  '11RAYJR123A',
#  '11RAYJR205A',
#  '09RAYJC016B',
#  '11RAYJR178A',
#  'BG120',
#  'BG133AN',
#  'BG121N',
#  'NB18255',
#  'BG126N',
#  'P7',
#  'U8',
#  'PT11',
#  '14AKMC074',
#  '14AKMC073',
#  '14AKMC076',
#  '14AKMC075',
#  '2-3-5-2017',
#  '1-3-5-2017',
#  '51-P-27',
#  '51-P-31',
#  'LDM254',
#  'BW8-1',
#  'MRB-7B',
#  'HB7683J',
#  'ERV005',
#  'CARTWRIGHT',
#  'K10-700',
#  '12AKBJ008',
#  '12AKBJ002',
#  '12AKBJ001',
#  'CM146',
#  'CM148',
#  'CM151',
#  'PAKSE16-A-1KS',
#  'CM150',
#  '310112-4',
#  '11K4',
#  '11-K-4',
#  'FELMLEE',
#  'PF11A',
#  'SG104',
#  'PF9',
#  'WU-09-05B',
#  '69L-2010',
#  'PAV-1',
#  '707-6',
#  '12AKMC018',
#  '12AKMC023',
#  '12AKMC024',
#  '12AKMC020',
#  '12AKMC019',
#  '12AKMC027',
#  '12AKMC026',
#  '12AKMC030',
#  '12AKMC028',
#  '12AKMC029',
#  '12AKMC021',
#  '12AKMC022',
#  'SDE15-A-2',
#  'SRD15-F-1',
#  'HALL-AA-15',
#  '12MHB9',
#  'HALL-AA-11',
#  'HALL-AA-14A',
#  'HALL-AA-13',
#  'HB76-51',
#  'CM80-3',
#  'UW98E',
#  'ADAKG',
#  'KAG34',
#  'GCPS0708',
#  'FERRARO',
#  'HAL-313',
#  '86-O-05',
#  '83PB30',
#  '85ARJ056',
#  '86RJ50A',
#  '86ARJ89',
#  '77AWS96',
#  '72-41-A',
#  'P5-543-3',
#  '88AWS8C',
#  '77AWS082A',
#  '78AWS126',
#  'D-1',
#  '17JF26',
#  'ES-13-11',
#  'AT80-61A',
#  'PE-1362',
#  'WA-361',
#  'TA-12',
#  '15-006',
#  'TA-1142',
#  'PE-300',
#  '15-020',
#  'WA-100',
#  '15CH',
#  'PIG-12-68',
#  'MIO-12-13',
#  'PIG-12-17A',
#  'PIG-12-60',
#  'PIG-12-59',
#  'PIG-12-28',
#  'PIG-12-35',
#  'PIG-12-37',
#  'PIG-12-56',
#  '2389-92',
#  '2534',
#  '2546',
#  '2548',
#  '90-O-19',
#  '90-O-30',
#  '90-O-32',
#  '90-O-33',
#  '90-O-34',
#  '90-O-49',
#  'AV-1',
#  'AV-40',
#  'AV-41',
#  'AV-44',
#  'AV-58',
#  'AV-59',
#  'AZLP-08-01',
#  'AZLP-08-02',
#  'AZLP-08-04',
#  'Base of the lower Trout Peak Trachyandesite',
#  'CopperLake stock',
#  'Fish Mountain porphyry',
#  'K-07-01B',
#  'K-07-01C',
#  'Langford Formation ash-flow tuff',
#  'NE-08-01',
#  'PAR-129',
#  'PAR-219',
#  'PAR-222',
#  'SR413-4.0',
#  'SR781-21.2',
#  'Top of the lower Trout Peak Trachyandesite',
#  'Upper Trout Peak Trachyandesite',
#  '83035']

# %% [markdown]
# Now we will create a list of rows from `df1` that corresponds to the name of the sample in the list `Missing`.

# %%
indexs = []

dfm.sample_name = dfm.sample_name.astype('str')
for i, series in dfm.iterrows():
    for ele in Missing:
        if series.sample_name == ele:
            indexs.append(series)
indexs = pd.DataFrame(indexs)

# %% [markdown]
# Now that we have a dataframe of all the missing samples, we can export it to an excel file where we can easily see the data and add information as we find the samples.
#
# The code below is how to export and save a pandas dataframe as an excell sheet. Make sure to have `xlsxwriter` downloaded first. Pandas uses it as the engine to convert the dataframe.

# %% [markdown]
# `writer = pd.ExcelWriter('MissingMetadata.xlsx', engine='xlsxwriter')
# indexs.to_excel(writer, sheet_name='MissingMetadata')
# writer.save()`
